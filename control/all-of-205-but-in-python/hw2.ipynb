# %% [markdown]
# # Homework 2 but in Python
# Compeltely unfinished because I realized I did the wrong problems from the wrong homework

# %%
import control as ct
import matplotlib.pyplot as plt
import numpy as np
from math import pi
from pprint import pprint

s = ct.tf("s")

RAD_TO_DEG = 180/pi
DEG_TO_RAD = pi/180

# %%
L1 = (s+7)*(s+3) / (s*(s+10)*(s+1)*(s+11))
L1.name = 'L(s) - Part (a)'

# %%
plt.figure(figsize=(12,8))
ct.bode(L1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(12,8))
#       2 ct.bode(L1)
#
# NameError: name 'plt' is not defined
